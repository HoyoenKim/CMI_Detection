# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/Trial"
# Out:
# /content/drive/MyDrive/Trial

# %%
# !git clone https://github.com/HoyoenKim/CMI_Detection.git
# Out:
# fatal: destination path 'CMI_Detection' already exists and is not an empty directory.

# %%
cd "/content/drive/MyDrive/Trial/CMI_Detection"
# Out:
# /content/drive/MyDrive/Trial/CMI_Detection

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install pytorch_lightning segmentation_models_pytorch==0.3.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 60.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 57.0 MB/s eta 0:00:00
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=d8f28845df8d73f3ae85c3ada8ad0f15638c0c532e69900aa85cc96fb202ff37
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60944 sha256=179c0afea3859cb857532c243ed3b64688d6b07bce884c3a19351900c2bacbd2
# ...

# %%
dataset="seg"
feature_extractor="CNN"
model="Spec2DCNN"
decoder="UNet1DDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=40
score_th=0.005
feature_args="anglez,enmo,hour_sin,hour_cos,anglez_diff,enmo_diff"
epochs=5

# %%
# !python main.py "train" 1 0 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos', 'anglez_diff', 'enmo_diff']
# 100% 277/277 [36:20<00:00,  7.87s/it]

# %%
dataset="seg"
feature_extractor="LSTM"
model="Spec2DCNN"
decoder="TransformerDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=100
score_th=0.001
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=50

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 100 and score_th with 0.001
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# use old series ids
# Seed set to 42
# 2023-11-29 00:35:38,739 - INFO:train.py - Set Up DataModule
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100% 83.3M/83.3M [00:00<00:00, 273MB/s]
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
dataset="seg"
feature_extractor="PANNs"
model="Spec2DCNN"
decoder="TransformerDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=100
score_th=0.001
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=50

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 100 and score_th with 0.001
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# use old series ids
# Seed set to 42
# 2023-11-29 02:11:15,926 - INFO:train.py - Set Up DataModule
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
dataset="seg"
feature_extractor="LSTM"
model="TransformerAutoModel"
decoder="TransformerDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=4
distance=100
score_th=0.001
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=20

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 100 and score_th with 0.001
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Seed set to 42
# 2023-11-28 08:46:33,937 - INFO:train.py - Set Up DataModule
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
datasets = ["seg"]
feature_extractors = ["LSTM"]
models = ["Spec2DCNN"]
decoders = ["UNet1DDecoder"]

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=40
score_th=0.005
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=20

# %%
for dataset in datasets:
    for feature_extractor in feature_extractors:
        for model in models:
            for decoder in decoders:
              # !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Seed set to 42
# 2023-11-28 07:19:53,694 - INFO:train.py - Set Up DataModule
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100% 83.3M/83.3M [00:02<00:00, 35.7MB/s]
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
datasets = ["seg"]
feature_extractors = ["CNN"]
models = ["Spec2DCNN"]
decoders = ["TransformerCNNDecoder"]

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=40
score_th=0.005
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=20

# %%
for dataset in datasets:
    for feature_extractor in feature_extractors:
        for model in models:
            for decoder in decoders:
              # !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Seed set to 42
# 2023-11-28 07:56:46,944 - INFO:train.py - Set Up DataModule
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Trial/CMI_Detection/main.py", line 61, in <module>
#     train(config, env)
#   File "/content/drive/MyDrive/Trial/CMI_Detection/train/train.py", line 53, in train
#     model = PLSleepModel(cfg, datamodule.valid_event_df, len(cfg["features"]), len(cfg["labels"]), cfg["duration"])
#   File "/content/drive/MyDrive/Trial/CMI_Detection/model/model.py", line 19, in __init__
#     self.model = get_model(
#   File "/content/drive/MyDrive/Trial/CMI_Detection/model/common.py", line 85, in get_model
#     decoder = get_decoder(cfg["decoder"], feature_extractor.height, n_classes, num_timesteps)
#   File "/content/drive/MyDrive/Trial/CMI_Detection/model/common.py", line 67, in get_decoder
# ...

# %%
datasets = ["seg"]
feature_extractors = ["CNN"]
models = ["Spec2DCNN"]
decoders = ["MLPDecoder"]

env="colab"
num_workers=2
downsample_rate=2
batch_size=32
distance=40
score_th=0.005
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=20

# %%
for dataset in datasets:
    for feature_extractor in feature_extractors:
        for model in models:
            for decoder in decoders:
              # !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Seed set to 42
# 2023-11-28 08:24:43,137 - INFO:train.py - Set Up DataModule
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
dataset = "detr"
feature_extractor = "LSTM"
model = "DETR2DCNN"
decoder = "TransformerDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=16
distance=40
score_th=0.005
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=1

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Other train fn
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/238 [00:00<?, ?it/s]
#   0% 1/238 [00:02<09:17,  2.35s/it]
#   1% 2/238 [00:03<05:40,  1.44s/it]
#   1% 3/238 [00:03<04:30,  1.15s/it]
#   2% 4/238 [00:04<03:57,  1.02s/it]
#   2% 5/238 [00:05<03:38,  1.06it/s]
#   3% 6/238 [00:06<03:27,  1.12it/s]
#   3% 7/238 [00:07<03:19,  1.16it/s]
#   3% 8/238 [00:07<03:14,  1.18it/s]
#   4% 9/238 [00:08<03:10,  1.20it/s]
#   4% 10/238 [00:09<03:08,  1.21it/s]
#   5% 11/238 [00:10<03:06,  1.22it/s]
#   5% 12/238 [00:11<03:04,  1.23it/s]
#   5% 13/238 [00:12<03:02,  1.23it/s]
#   6% 14/238 [00:12<03:01,  1.23it/s]
#   6% 15/238 [00:13<03:00,  1.23it/s]
#   7% 16/238 [00:14<02:59,  1.24it/s]
#   7% 17/238 [00:15<02:58,  1.24it/s]
#   8% 18/238 [00:16<02:57,  1.24it/s]
#   8% 19/238 [00:16<02:56,  1.24it/s]
#   8% 20/238 [00:17<02:55,  1.24it/s]
#   9% 21/238 [00:18<02:55,  1.24it/s]
# ...

# %%
dataset = "centernet"
feature_extractor = "CNN"
model = "CenterNet"
decoder = "UNet1DDecoder"

env="colab"
num_workers=2
downsample_rate=2
batch_size=8
distance=100
score_th=0.001
feature_args="anglez,enmo,hour_sin,hour_cos"
epochs=50

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 100 and score_th with 0.001
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Other train fn
#   0% 0/50 [00:00<?, ?it/s]Training loss 0.1594532335829185
# Validation loss 0.002887471376424924
# Epoch 0, Train Loss: 0.1594532335829185, Validation Loss: 0.002887471376424924
# val_score:  0.38233649425510685
# save model with best_val_score:  0.38233649425510685
#   2% 1/50 [03:32<2:53:27, 212.39s/it]Training loss 0.14124663539652554
# Validation loss 0.001401072259318773
# Epoch 1, Train Loss: 0.14124663539652554, Validation Loss: 0.001401072259318773
# val_score:  0.5956355879233587
#   4% 2/50 [06:38<2:37:32, 196.93s/it]Training loss 0.1407371327999503
# Validation loss 0.0010203330261029575
# Epoch 2, Train Loss: 0.1407371327999503, Validation Loss: 0.0010203330261029575
# val_score:  0.602785074813646
#   6% 3/50 [09:40<2:28:54, 190.10s/it]Training loss 0.14064621747289813
# Validation loss 0.0011733979678907273
# ...

# %%
# !python main.py "train" 0 1 $dataset $feature_extractor $model $decoder $env $num_workers $downsample_rate $batch_size $distance $score_th $feature_args $epochs
# Out:
# Post-process: distance with 40 and score_th with 0.005
# Features:  ['anglez', 'enmo', 'hour_sin', 'hour_cos']
# Seed set to 42
# 2023-11-24 12:04:22,864 - INFO:train.py - Set Up DataModule
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:565: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
